# %%
import glob
import pandas as pd
import sys
sys.path.append('..')
from src import paths

# %%
raw_folder = paths.raw_path()

# %% [markdown]
# RAW MATCH PARQUET FOLDER

# %%
event_df_sample = pd.read_parquet(raw_folder + 'raw_match_parquet/event_11998447.parquet')
event_df_sample
# Out:
#    match_id  first_to_serve home_team_seed away_team_seed custom_id  \
# 0  11998447               1              4           None   FQAsyUF
#
#    winner_code  default_period_count  start_datetime      match_slug  \
# 0            1                     3      1706794200  martinez-coric
#
#    final_result_only
# 0              False

# %%
home_team_df_sample = pd.read_parquet(raw_folder + 'raw_match_parquet/home_team_11998447.parquet')
home_team_df_sample
# Out:
#    match_id      name         slug gender  user_count   residence  \
# 0  11998447  Ćorić B.  coric-borna      M       12414  Dubai, UAE
#
#         birthplace  height  weight         plays turned_pro  current_prize  \
# 0  Zagreb, Croatia    1.88      85  right-handed       2013         208593
#
#    total_prize  player_id  current_rank name_code  country     full_name
# 0      9947986      64580            31       COR  Croatia  Ćorić, Borna

# %%
away_team_df_sample = pd.read_parquet(raw_folder + 'raw_match_parquet/away_team_11998447.parquet')
away_team_df_sample
# Out:
#    match_id         name            slug gender  user_count        residence  \
# 0  11998447  Martínez P.  martinez-pedro      M        2621  Valencia, Spain
#
#       birthplace  height  weight         plays turned_pro  current_prize  \
# 0  Alzira, Spain    1.85      76  right-handed       2016          39448
#
#    total_prize  player_id  current_rank name_code country        full_name
# 0      2732689      77223           101       MAR   Spain  Martinez, Pedro

# %%
home_team_score_df_sample = pd.read_parquet(raw_folder + 'raw_match_parquet/home_team_score_11998447.parquet')
home_team_score_df_sample
# Out:
#    match_id  current_score  display_score  period_1  period_2 period_3  \
# 0  11998447              2              2         6         6     None
#
#   period_4 period_5 period_1_tie_break period_2_tie_break period_3_tie_break  \
# 0     None     None               None               None               None
#
#   period_4_tie_break period_5_tie_break normal_time
# 0               None               None        None

# %%
away_team_score_df_sample = pd.read_parquet(raw_folder + 'raw_match_parquet/away_team_score_11998447.parquet')
away_team_score_df_sample
# Out:
#    match_id  current_score  display_score  period_1  period_2 period_3  \
# 0  11998447              0              0         4         0     None
#
#   period_4 period_5 period_1_tie_break period_2_tie_break period_3_tie_break  \
# 0     None     None               None               None               None
#
#   period_4_tie_break period_5_tie_break normal_time
# 0               None               None        None

# %%
round_df_sample = pd.read_parquet(raw_folder + 'raw_match_parquet/round_11998447.parquet')
round_df_sample
# Out:
#    match_id  round_id         name         slug  cup_round_type
# 0  11998447         5  Round of 16  round-of-16               8

# %%
time_df_sample = pd.read_parquet(raw_folder + 'raw_match_parquet/time_11998447.parquet')
time_df_sample
# Out:
#    match_id  period_1  period_2 period_3 period_4 period_5  \
# 0  11998447      3741      1913     None     None     None
#
#    current_period_start_timestamp
# 0                      1706798459

# %%
season_df_sample = pd.read_parquet(raw_folder + 'raw_match_parquet/season_11998447.parquet')
season_df_sample
# Out:
#    match_id  season_id                                      name  year
# 0  11998447      55448  ATP Montpellier, France Men Singles 2024  2024

# %%
tournament_df_sample = pd.read_parquet(raw_folder + 'raw_match_parquet/tournament_11998447.parquet')
tournament_df_sample
# Out:
#    match_id  tournament_id      tournament_name     tournament_slug  \
# 0  11998447         126168  Montpellier, France  montpellier-france
#
#   tournament_unique_id tournament_category_name tournament_category_slug  \
# 0                 None                      ATP                      atp
#
#    user_count       ground_type  tennis_points  has_event_player_statistics  \
# 0        2155  Hardcourt indoor            250                        False
#
#    crowd_sourcing_enabled  has_performance_graph_feature  \
# 0                   False                          False
#
#    display_inverse_home_away_teams  priority  competition_type
# 0                            False         0                 2

# %%
venue_df_sample = pd.read_parquet(raw_folder + 'raw_match_parquet/venue_11998447.parquet')
venue_df_sample
# Out:
#    match_id         city                  stadium  venue_id country
# 0  11998447  Montpellier  Court Patrice Dominguez     20333  France

# %% [markdown]
# RAW TENNIS POWER PARQUET FOLDER

# %%
power_df_sample = pd.read_parquet(raw_folder + 'raw_tennis_power_parquet/power_11998447.parquet')
power_df_sample
# Out:
#     match_id  set_num  game_num  value  break_occurred
# 0   11998447        1         1 -10.00           False
# 1   11998447        1         2  10.00           False
# 2   11998447        1         3  15.68            True
# 3   11998447        1         4  30.32           False
# 4   11998447        1         5 -10.00           False
# 5   11998447        1         6  10.00           False
# 6   11998447        1         7 -35.16           False
# 7   11998447        1         8  46.40           False
# 8   11998447        1         9 -46.42           False
# 9   11998447        1        10  10.00           False
# 10  11998447        2         1  34.70            True
# 11  11998447        2         2  39.64           False
# 12  11998447        2         3  52.78            True
# 13  11998447        2         4  41.20           False
# 14  11998447        2         5  33.42            True
# 15  11998447        2         6  10.20           False

# %% [markdown]
# RAW STATISTICS PARQUET FOLDER

# %%
statistics_df_sample = pd.read_parquet(raw_folder + 'raw_statistics_parquet/statistics_11998447.parquet')
statistics_df_sample
# Out:
#     match_id period statistic_category_name              statistic_name  \
# 0   11998447    ALL                 service                        aces
# 1   11998447    ALL                 service               double_faults
# 2   11998447    ALL                 service                 first_serve
# 3   11998447    ALL                 service                second_serve
# 4   11998447    ALL                 service          first_serve_points
# 5   11998447    ALL                 service         second_serve_points
# 6   11998447    ALL                 service        service_games_played
# 7   11998447    ALL                 service          break_points_saved
# 8   11998447    ALL                  points                       total
# 9   11998447    ALL                  points          service_points_won
# 10  11998447    ALL                  points         receiver_points_won
# 11  11998447    ALL                  points         max_points_in_a_row
# ...
