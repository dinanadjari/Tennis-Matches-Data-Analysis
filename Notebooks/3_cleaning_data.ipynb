# %%
import glob
import pandas as pd
import numpy as np
import sys

sys.path.append('..')
from src import paths
from src import load

# %%
raw = paths.raw_path()
clean = paths.clean_path()

# %% [markdown]
# CLEANING HOME_TEAM TABLE

# %%
home_team_df = load.to_load(raw + 'raw_match_parquet/home_team_*.parquet')

# %%
load.to_clean(home_team_df, 10)
home_team_df.to_parquet(clean + 'home_team.parquet')

# %% [markdown]
# CLEANING HOME TEAM SCORE TABLE

# %%
home_score_df = load.to_load(raw + 'raw_match_parquet/home_team_score*.parquet')

# %%
load.to_clean(home_score_df, 3)
home_score_df.to_parquet(clean + '/home_score.parquet')

# %% [markdown]
# CLEANING AWAY_TEAM TABLE

# %%
away_team_df = load.to_load(raw + 'raw_match_parquet/away_team_*.parquet')

# %%
load.to_clean(away_team_df, 10)
away_team_df.to_parquet(clean + 'away_team.parquet')

# %% [markdown]
# CLEANING AWAY TEAM SCORE TABLE

# %%
away_score_df = load.to_load(raw + 'raw_match_parquet/away_team_score*.parquet')

# %%
load.to_clean(away_score_df, 3)
away_score_df.to_parquet(clean + 'away_score.parquet')

# %% [markdown]
# CLEANING EVENT TABLE

# %%
event_df = load.to_load(raw + 'raw_match_parquet/event_*.parquet')

# %%
load.to_clean(event_df, 3)
event_df.to_parquet(clean + 'event.parquet')

# %% [markdown]
# CLEANING TIME TABLE

# %%
time_df = load.to_load(raw + 'raw_match_parquet/time_*.parquet')

# %%
load.to_clean(time_df, 2)
time_df.to_parquet(clean + 'time.parquet')

# %% [markdown]
# CLEANING TOURNAMENT TABLE

# %%
tournament_df = load.to_load(raw + 'raw_match_parquet/tournament_*.parquet')

# %%
load.to_clean(tournament_df, 6)
tournament_df.to_parquet(clean + 'tournament.parquet')

# %% [markdown]
# CLEANING POWER TABLE

# %%
power_df = load.to_load(raw + 'raw_tennis_power_parquet/power_*.parquet')

# %%
load.to_clean(power_df, 4)
power_df.to_parquet(clean+ 'power.parquet')

# %% [markdown]
# CLEANIN STATISTICS (PERIOD) TABLE

# %%
statistics_df = load.to_load(raw + 'raw_statistics_parquet/statistics_*.parquet')

# %%
load.to_clean(statistics_df, 8)
statistics_df.to_parquet(clean + 'statistics.parquet')

# %% [markdown]
# CLEANING ROUND TABLE

# %%
round_df = load.to_load(raw + 'raw_match_parquet/round_*.parquet')

# %%
load.to_clean(round_df, 3)
round_df.to_parquet(clean + 'round.parquet')
